# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import stochastic_block_model as sbm

G = sbm.stochastic_block_model(100, 4, 5, 0.99)
nx.draw(G)

# %%
G = sbm.stochastic_block_model(100, 4, 5, 0.50)
nx.draw(G)

# %%
G = sbm.stochastic_block_model(100, 4, 5, 0.01)
nx.draw(G)
